# %%
# For Python 3.0 and later
from urllib.request import urlopen
import pandas as pd
import certifi
import json
from pathlib import Path
# %matplotlib inline

# %%
def get_jsonparsed_data2(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v3/quote/%5EGSPC,%5EDJI,%5EIXIC?&apikey=eef11245e039afd02560c03e5e86851d")

# %%
test2 = urlopen(url)
test2 = json.loads(test2.read())
test2 = pd.DataFrame(test2)
test2
# Out:
#   symbol                          name      price  changesPercentage  \
# 0   ^DJI  Dow Jones Industrial Average  33536.700          -0.625699
# 1  ^GSPC                       S&P 500   3957.250          -0.893578
# 2  ^IXIC              NASDAQ Composite  11196.221          -1.122553
#
#       change     dayLow    dayHigh  yearHigh   yearLow marketCap  ...  \
# 0 -211.16016  33533.960  33964.300  36952.65  28660.94      None  ...
# 1  -35.67993   3956.400   4008.970   4818.62   3491.58      None  ...
# 2 -127.11035  11167.165  11350.125  16212.23  10088.83      None  ...
#
#        volume   avgVolume  exchange      open previousClose   eps    pe  \
# 0   360586154   357696562     INDEX  33662.05     33747.860  None  None
# 1  2615043000  4352211406     INDEX   3977.97      3992.930  None  None
# 2  4383429000  4742622812     INDEX  11233.90     11323.331  None  None
#
#   earningsAnnouncement sharesOutstanding   timestamp
# 0                 None              None  1668474428
# 1                 None              None  1668474428
# 2                 None              None  1668474428
#
# [3 rows x 22 columns]
